# %%
import pandas as pd
from pandas import read_csv
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from math import log2
import sys
import itertools
from sklearn.linear_model import LogisticRegression

# %matplotlib inline

# %% [markdown]
# # Settings For The Figures

# %%
# Set the global default size of matplotlib figures
plt.rc('figure', figsize=(12, 7))

# Size of matplotlib figures that contain subplots
fizsize_with_subplots = (10, 10)

# Size of matplotlib histogram bins
bin_size = 10

# %% [markdown]
# # Importing the Datatset

# %%
path = './crime.csv'
dataset = read_csv(path, sep=';', na_values=".", header='infer', dtype=str)
dataset
# Out:
#                                                   TYPE  YEAR MONTH DAY HOUR  \
# 0                                          Other Theft  2003     5  12   16
# 1                                          Other Theft  2003     5   7   15
# 2                                          Other Theft  2003     4  23   16
# 3                                          Other Theft  2003     4  20   11
# 4                                          Other Theft  2003     4  12   17
# 5                                          Other Theft  2003     3  26   20
# 6                    Break and Enter Residential/Other  2003     3  10   12
# 7                                             Mischief  2003     6  28    4
# 8                                          Other Theft  2003     2  16    9
# 9                    Break and Enter Residential/Other  2003     7   9   18
# 10                                         Other Theft  2003     1  31   19
# ...

# %% [markdown]
# # Selected Learning Features

# %%
X = dataset['PRIORITY']
Y = dataset['TYPE']
Z = dataset['NEIGHBOURHOOD']

# %% [markdown]
# # Looking at the types of crimes that occured in 2003 and 2017

# %%
Y_crimes = pd.crosstab(dataset['TYPE'], dataset['YEAR'])

# %% [markdown]
# # Plotting the relationship of Types of Crimes that occured between 2003 and 2017

# %%
Y_crimes.plot(kind='bar', stacked=True, color=['green','blue'], grid=True, title='Types of Crimes in time')
plt.xlabel('TYPE OF CRIMES')
plt.ylabel('RATE OF CRIMES')
# Out:
# Text(0,0.5,'RATE OF CRIMES')

# %%
Z_elements = sorted(Z.unique())
Z_elements
# Out:
# ['Arbutus Ridge',
#  'Central Business District',
#  'Dunbar-Southlands',
#  'Fairview',
#  'Grandview-Woodland',
#  'Hastings-Sunrise',
#  'Kensington-Cedar Cottage',
#  'Kerrisdale',
#  'Kitsilano',
#  'Marpole',
#  'Mount Pleasant',
#  'Renfrew-Collingwood',
#  'Shaughnessy',
#  'Stanley Park',
#  'Strathcona',
#  'Sunset',
#  'Victoria-Fraserview',
#  'West End',
#  'West Point Grey']

# %%
# Looking at the ratio of crimes that occured in 2003 and 2017
Z_class = dataset.groupby('NEIGHBOURHOOD').size()

# %% [markdown]
# # Checking The Rate of Crimes in each NEIGHBOURHOOD

# %%
Z_class.plot(kind='bar', title = 'Number of Data Points used')

# %% [markdown]
# # Looking at Types of Crimes in each NEIGHBOURHOOD that occured in 2003 and 2017

# %%
Z_crimes = pd.crosstab(dataset['NEIGHBOURHOOD'], dataset['YEAR'])

# %%
Z_crimes.plot(kind='bar', stacked=True, color=['green','blue'], grid=True, title='Places the Crimes Occured in Time')
plt.xlabel('NEIGHBOURHOOD')
plt.ylabel('RATE OF CRIMES')
# Out:
# Text(0,0.5,'RATE OF CRIMES')

# %%
date = pd.crosstab(dataset['MONTH'], dataset['YEAR'])

# %%
date.plot(kind='bar', stacked=True, color=['green','blue'], grid=True, title='Places the Crimes Occured in Time')
plt.xlabel('MONTH')
plt.ylabel('RATE OF CRIMES')
# Out:
# Text(0,0.5,'RATE OF CRIMES')

# %% [markdown]
# # Checking the Rate of Crimes that occurred everyday in 2003 and 2017

# %%
day = pd.crosstab(dataset['DAY'], dataset['YEAR'])

# %%
day.plot(kind='bar', stacked=True, color=['green','blue'], grid=True, title='Places the Crimes Occured in Time')
plt.xlabel('DAY')
plt.ylabel('RATE OF CRIMES')
# Out:
# Text(0,0.5,'RATE OF CRIMES')

# %% [markdown]
# # Checking the Rate of Crimes that occurred Hourly in 2003 and 2017

# %%
time = pd.crosstab(dataset['HOUR'], dataset['YEAR'])

# %%
time.plot(kind='bar', stacked=True, color=['green','blue'], grid=True, title='Places the Crimes Occured in Time')
plt.xlabel('HOUR')
plt.ylabel('RATE OF CRIMES')
# Out:
# Text(0,0.5,'RATE OF CRIMES')

# %% [markdown]
# # Defining Instances

# %%
Y_inst = pd.crosstab(dataset['TYPE'], dataset['PRIORITY'])

# %%
Y_inst.plot(kind='bar', stacked=True, color=['green','blue'], grid=True, title='Places the Crimes Occured in Time')
plt.xlabel('TYPE')
plt.ylabel('RATE OF CRIMES')
# Out:
# Text(0,0.5,'RATE OF CRIMES')

# %%
Z_inst = pd.crosstab(dataset['NEIGHBOURHOOD'], dataset['PRIORITY'])

# %%
Z_inst.plot(kind='bar', stacked=True, color=['red','blue'], grid=True, title='NEIGHBOURHOOD with Respect to PRIORITY')
plt.xlabel('NEIGHBOURHOOD')
plt.ylabel('RATE OF CRIMES')
# Out:
# Text(0,0.5,'RATE OF CRIMES')

# %%
ind_data = dataset[['TYPE','PRIORITY']]

# %%
x0 = ind_data[ind_data['TYPE'] == 'Other Theft']
x1 = ind_data[ind_data['TYPE'] == 'Break and Enter Commercial']
x2 = ind_data[ind_data['TYPE'] == 'Break and Enter Residential/Other']
x3 = ind_data[ind_data['TYPE'] == 'Mischief']
x4 = ind_data[ind_data['TYPE'] == 'Theft from Vehicle']
x5 = ind_data[ind_data['TYPE'] == 'Theft of Bicycle']
x6 = ind_data[ind_data['TYPE'] == 'Theft of Vehicle']
x7 = ind_data[ind_data['TYPE'] == 'Vehicle Collision or Pedestrian Struck (with Injury)']

# %% [markdown]
# # Entropy Calculation

# %%
def entropy(element):
    """
    Calculate Shannon entropy
    :param attribute_data: data from a single feature/attribute
    :return: a float representing the Shannon entropy
    H(X) = -sum(Prob(X) * log2(Prob(X)))
    """
    _, val_freqs = np.unique(element, return_counts=True)
    val_probs = val_freqs / len(element)
    return -np.sum(val_probs * (np.log2(val_probs)))

# %% [markdown]
# # Counting Elements in the Dictionary

# %%
def get_count_dict(elements):
    """
    Return the unique values and their frequencies as a dictionary
    :param data: a 1-D numpy array
    :return:
    """
    data_values, data_freqs = np.unique(elements, return_counts=True)
    return dict(zip(data_values, data_freqs))

# %% [markdown]
# # Calculating the Info Gain

# %%
def info_gain(X, element):
    """
    Calculate information gain
    :param attribute_data: data from single attribute
    :param labels:
    :return: a float representing information gain
    Gain(X,Y) = H(X) - H(X, Y)
    """
    attr_val_counts = get_count_dict(element)
    print ("attr_val_counts = ",attr_val_counts)
    total_count = len(X)
    print ("total_count = ",total_count)
    S = 0
    for attr_val, attr_val_count in attr_val_counts.items():
        proba = attr_val_count / total_count
        print ('proba =',proba)
        E = - np.sum(proba * (np.log2(proba)))
        print ('attr_val_count =',attr_val_count)
        print ('attr_val =',attr_val)
        print ("E = ",E)
        gain = entropy(X) - ((attr_val_count/ total_count) * E)
        print ("Gain = ",gain)

    return gain

# %% [markdown]
# # Results Of Information Gain for all the Crimes

# %% [markdown]
# # Element with Highest Gain, This come first on the node

# %%
get_count_dict(x6)
# Out:
# {'NO': 1, 'Theft of Vehicle': 3, 'YES': 2}

# %%
gain7 = info_gain(X, x6)
f = dataset[dataset['TYPE'] == 'Theft of Vehicle']
d = f[f['PRIORITY'] == 'YES']
d
# Out:
# attr_val_counts =  {'NO': 1, 'Theft of Vehicle': 3, 'YES': 2}
# total_count =  222
# proba = 0.0045045045045
# attr_val_count = 1
# attr_val = NO
# E =  0.03510998138
# Gain =  0.986628567199
# proba = 0.0135135135135
# attr_val_count = 3
# attr_val = Theft of Vehicle
# E =  0.083911531968
# Gain =  0.985652780647
# proba = 0.00900900900901
# attr_val_count = 2
# attr_val = YES
# E =  0.0612109537509
# Gain =  0.986235270234
#                  TYPE  YEAR MONTH DAY HOUR MINUTE      HUNDRED_BLOCK  \
# 200  Theft of Vehicle  2017     1  11   22      0    65XX FLEMING ST
# 212  Theft of Vehicle  2017     3  10    0      0  36XX CAMBRIDGE ST
#
#            NEIGHBOURHOOD     Latitude     Longitude PRIORITY
# 200  Victoria-Fraserview  49.22516007  -123.0731018      YES
# 212     Hastings-Sunrise  49.28665438  -123.0252203      YES

# %% [markdown]
# # This Element come Second

# %%
get_count_dict(x7)
# Out:
# {'Vehicle Collision or Pedestrian Struck (with Injury)': 3, 'YES': 3}

# %%
gain8 = info_gain(X, x7)
f = dataset[dataset['TYPE'] == 'Vehicle Collision or Pedestrian Struck (with Injury)']
d = f[f['PRIORITY'] == 'YES']
d
# Out:
# attr_val_counts =  {'Vehicle Collision or Pedestrian Struck (with Injury)': 3, 'YES': 3}
# total_count =  222
# proba = 0.0135135135135
# attr_val_count = 3
# attr_val = Vehicle Collision or Pedestrian Struck (with Injury)
# E =  0.083911531968
# Gain =  0.985652780647
# proba = 0.0135135135135
# attr_val_count = 3
# attr_val = YES
# E =  0.083911531968
# Gain =  0.985652780647
#                                                   TYPE  YEAR MONTH DAY HOUR  \
# 188  Vehicle Collision or Pedestrian Struck (with I...  2017     3  25   19
# 210  Vehicle Collision or Pedestrian Struck (with I...  2017     7  10    9
# 221  Vehicle Collision or Pedestrian Struck (with I...  2017     6   6   17
#
#     MINUTE          HUNDRED_BLOCK   NEIGHBOURHOOD     Latitude     Longitude  \
# 188     30    X STANLEY PARK CSWY    Stanley Park  49.29452892   -123.136762
# 210     20  YUKON ST / W 10TH AVE  Mount Pleasant    49.262208  -123.1129226
# ...

# %% [markdown]
# # This Element come Third

# %%
get_count_dict(x5)
# Out:
# {'Theft of Bicycle': 4, 'YES': 4}

# %%
gain6 = info_gain(X, x5)
gain8 = info_gain(X, x7)
f = dataset[dataset['TYPE'] == 'Theft of Bicycle']
d = f[f['PRIORITY'] == 'YES']
d
# Out:
# attr_val_counts =  {'Theft of Bicycle': 4, 'YES': 4}
# total_count =  222
# proba = 0.018018018018
# attr_val_count = 4
# attr_val = Theft of Bicycle
# E =  0.104403889484
# Gain =  0.984905569106
# proba = 0.018018018018
# attr_val_count = 4
# attr_val = YES
# E =  0.104403889484
# Gain =  0.984905569106
# attr_val_counts =  {'Vehicle Collision or Pedestrian Struck (with Injury)': 3, 'YES': 3}
# total_count =  222
# proba = 0.0135135135135
# attr_val_count = 3
# attr_val = Vehicle Collision or Pedestrian Struck (with Injury)
# E =  0.083911531968
# Gain =  0.985652780647
# proba = 0.0135135135135
# attr_val_count = 3
# attr_val = YES
# E =  0.083911531968
# Gain =  0.985652780647
#                  TYPE  YEAR MONTH DAY HOUR MINUTE    HUNDRED_BLOCK  \
# 194  Theft of Bicycle  2017     6  20   19      0   19XX WHYTE AVE
# 204  Theft of Bicycle  2017     4  22    8      0   2XX E 51ST AVE
# 206  Theft of Bicycle  2017     4  25   23      0  30XX W 12TH AVE
# ...

# %% [markdown]
# # This Element come Fourth

# %%
get_count_dict(x1)
# Out:
# {'Break and Enter Commercial': 8, 'NO': 8}

# %%
gain2 = info_gain(X, x1)
f = dataset[dataset['TYPE'] == 'Break and Enter Commercial']
d = f[f['PRIORITY'] == 'NO']
d
# Out:
# attr_val_counts =  {'Break and Enter Commercial': 8, 'NO': 8}
# total_count =  222
# proba = 0.036036036036
# attr_val_count = 8
# attr_val = Break and Enter Commercial
# E =  0.172771742932
# Gain =  0.980560711514
# proba = 0.036036036036
# attr_val_count = 8
# attr_val = NO
# E =  0.172771742932
# Gain =  0.980560711514
#                            TYPE  YEAR MONTH DAY HOUR MINUTE    HUNDRED_BLOCK  \
# 15   Break and Enter Commercial  2003     9  26    2     30  10XX ALBERNI ST
# 60   Break and Enter Commercial  2003     5  14    1      0  10XX BARCLAY ST
# 66   Break and Enter Commercial  2003    12  25    5     55   10XX BEACH AVE
# 106  Break and Enter Commercial  2003    11   2   18     30   10XX BEACH AVE
# 120  Break and Enter Commercial  2003     4   8    4     45  10XX BURNABY ST
# 124  Break and Enter Commercial  2003     9  16    1     45   10XX BEACH AVE
# 179  Break and Enter Commercial  2003     6  21   20     30  10XX BURRARD ST
# ...

# %% [markdown]
# # This Element come Fifth

# %%
get_count_dict(x2)
# Out:
# {'Break and Enter Residential/Other': 30, 'NO': 12, 'YES': 18}

# %%
gain3 = info_gain(X, x2)
f = dataset[dataset['TYPE'] == 'Break and Enter Residential/Other']
d = f[f['PRIORITY'] == 'YES']
d
# Out:
# attr_val_counts =  {'Break and Enter Residential/Other': 30, 'NO': 12, 'YES': 18}
# total_count =  222
# proba = 0.135135135135
# attr_val_count = 30
# attr_val = Break and Enter Residential/Other
# E =  0.390206117668
# Gain =  0.934056163826
# proba = 0.0540540540541
# attr_val_count = 12
# attr_val = NO
# E =  0.227538019764
# Gain =  0.974487367848
# proba = 0.0810810810811
# attr_val_count = 18
# attr_val = YES
# E =  0.293877637695
# Gain =  0.962958803698
#                                   TYPE  YEAR MONTH DAY HOUR MINUTE  \
# 6    Break and Enter Residential/Other  2003     3  10   12      0
# 9    Break and Enter Residential/Other  2003     7   9   18     15
# 42   Break and Enter Residential/Other  2003     6  30   23      0
# 47   Break and Enter Residential/Other  2003     1  25   15     39
# 97   Break and Enter Residential/Other  2003     4  20    0      0
# 114  Break and Enter Residential/Other  2003     9   9    9      0
# ...

# %% [markdown]
# # This Element come Sixth

# %%
get_count_dict(x0)
# Out:
# {'NO': 15, 'Other Theft': 34, 'YES': 19}

# %%
gain1 = info_gain(X, x0)
f = dataset[dataset['TYPE'] == 'Other Theft']
d = f[f['PRIORITY'] == 'YES']
d
# Out:
# attr_val_counts =  {'NO': 15, 'Other Theft': 34, 'YES': 19}
# total_count =  222
# proba = 0.0675675675676
# attr_val_count = 15
# attr_val = NO
# E =  0.262670626401
# Gain =  0.969038704971
# proba = 0.153153153153
# attr_val_count = 34
# attr_val = Other Theft
# E =  0.414578391231
# Gain =  0.923292732422
# proba = 0.0855855855856
# attr_val_count = 19
# attr_val = YES
# E =  0.303528282456
# Gain =  0.960809074472
#             TYPE  YEAR MONTH DAY HOUR MINUTE     HUNDRED_BLOCK  \
# 0    Other Theft  2003     5  12   16     15  9XX TERMINAL AVE
# 1    Other Theft  2003     5   7   15     20  9XX TERMINAL AVE
# 2    Other Theft  2003     4  23   16     40  9XX TERMINAL AVE
# 3    Other Theft  2003     4  20   11     15  9XX TERMINAL AVE
# 4    Other Theft  2003     4  12   17     45  9XX TERMINAL AVE
# 5    Other Theft  2003     3  26   20     45  9XX TERMINAL AVE
# 8    Other Theft  2003     2  16    9      2  9XX TERMINAL AVE
# ...

# %% [markdown]
# # This Element come Seventh

# %%
get_count_dict(x3)
# Out:
# {'Mischief': 38, 'NO': 17, 'YES': 21}

# %%
gain4 = info_gain(X, x3)
f = dataset[dataset['TYPE'] == 'Mischief']
d = f[f['PRIORITY'] == 'YES']
d
# Out:
# attr_val_counts =  {'Mischief': 38, 'NO': 17, 'YES': 21}
# total_count =  222
# proba = 0.171171171171
# attr_val_count = 38
# attr_val = Mischief
# E =  0.435885393741
# Gain =  0.912175706925
# proba = 0.0765765765766
# attr_val_count = 17
# attr_val = NO
# E =  0.283865772192
# Gain =  0.965049251226
# proba = 0.0945945945946
# attr_val_count = 21
# attr_val = YES
# E =  0.321820123041
# Gain =  0.956344276197
#          TYPE  YEAR MONTH DAY HOUR MINUTE              HUNDRED_BLOCK  \
# 7    Mischief  2003     6  28    4     13            40XX W 19TH AVE
# 22   Mischief  2003     1  23   23      0            40XX W 27TH AVE
# 24   Mischief  2003     6  29    0     30            40XX W 27TH AVE
# 33   Mischief  2003     8   5   22      0               11XX HARO ST
# 37   Mischief  2003     9   2    9     25            13XX FRANCES ST
# 38   Mischief  2003     3  18    0     30            40XX W 31ST AVE
# 59   Mischief  2003     4  13   22      0            40XX W 34TH AVE
# ...

# %% [markdown]
# # This Element come Eigth

# %%
get_count_dict(x4)
# Out:
# {'NO': 43, 'Theft from Vehicle': 102, 'YES': 59}

# %%
gain5 = info_gain(X, x4)
f = dataset[dataset['TYPE'] == 'Theft from Vehicle']
d = f[f['PRIORITY'] == 'YES']
d
# Out:
# attr_val_counts =  {'NO': 43, 'Theft from Vehicle': 102, 'YES': 59}
# total_count =  222
# proba = 0.193693693694
# attr_val_count = 43
# attr_val = NO
# E =  0.45869593604
# Gain =  0.897940210134
# proba = 0.459459459459
# attr_val_count = 102
# attr_val = Theft from Vehicle
# E =  0.51550915985
# Gain =  0.749931160337
# proba = 0.265765765766
# attr_val_count = 59
# attr_val = YES
# E =  0.508083766677
# Gain =  0.851755448944
#                    TYPE  YEAR MONTH DAY HOUR MINUTE           HUNDRED_BLOCK  \
# 28   Theft from Vehicle  2003     6  17   16     15        11XX MAINLAND ST
# 29   Theft from Vehicle  2003     6  13   12      0        11XX MAINLAND ST
# 30   Theft from Vehicle  2003     6  11   15      0        11XX MAINLAND ST
# 32   Theft from Vehicle  2003     4  21   17      0          11XX NOOTKA ST
# 34   Theft from Vehicle  2003     8  19    6     15       10XX BROUGHTON ST
# 51   Theft from Vehicle  2003     5  22   19      0        11XX MAINLAND ST
# ...

# %% [markdown]
# # Ploting The Confusion Matrix

# %%
# Generating the Confusion Matrix
data = pd.get_dummies(dataset, columns =['TYPE', 'NEIGHBOURHOOD'])

# %%
data.drop(data.columns[[1]], axis=1, inplace=True)

# %%
# Set the global default size of matplotlib figures
plt.rc('figure', figsize=(17, 10))

# Size of matplotlib figures that contain subplots
fizsize_with_subplots = (15, 12)

# Size of matplotlib histogram bins
bin_size = 24
sns.heatmap(data.corr(), annot=True, fmt='.2f') #It is normalized already
plt.show()

# %%
x = data.iloc[:, 8:-1]
x = x.as_matrix()

# %%
y = data.iloc[:, 7]

for i in range(len(y)):
    if y[i]=='YES':
        y[i] = 1
    if y[i]=='NO':
        y[i] = 0
        
y = np.array(y)
# Out:
# /Users/admin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/admin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %% [markdown]
# # Spliting the Stratisfied Train Test

# %%
def stratified_train_test_split(X, Y, test_size, random_seed=None):
    if test_size < 0 or test_size > 1:
        raise Exception("Fraction for split is not valid")

    np.random.seed(random_seed)

    X_train = []
    X_test = []
    y_train = []
    y_test = []

    zeros = np.sum(Y == 0)
    num_zeros = int(zeros * test_size)
    ones = np.sum(Y == 1)
    num_ones = int(ones * test_size)

    # For X Test

    index_zero = np.random.choice(range(zeros), size=num_zeros,replace=False)
    choice_x_zero = X[Y == 0]
    test_x_zero = choice_x_zero[index_zero]

    index_one = np.random.choice(range(ones), size=num_ones, replace=False)
    choice_x_one = X[Y == 1]
    test_x_one = choice_x_one[index_one]

    X_test = np.concatenate([test_x_one, test_x_zero])
    

    # For Y Test

    choice_y_zero = Y[Y == 0]
    test_y_zero = choice_y_zero[index_zero]

    choice_y_one = Y[Y == 1]
    test_y_one = choice_y_one[index_one]

    y_test = np.concatenate([test_y_zero, test_y_one])


    # For X Train

    train_index_zero = [i for i in range(num_zeros) if i not in index_zero]
    choose_x_zero = X[Y == 0]
    train_x_zero = choose_x_zero[train_index_zero]

    train_index_ones = [i for i in range(num_ones) if i not in index_one]
    choose_x_one = X[Y == 1]
    train_x_one = choose_x_one[train_index_ones]

    X_train = np.concatenate([train_x_zero, train_x_one])

    # For Y Train

    choose_y_zero = Y[Y == 0]
    train_y_zero = choose_y_zero[train_index_zero]

    choose_y_one = Y[Y == 1]
    train_y_one = choose_y_one[train_index_ones]

    y_train = np.concatenate([train_y_one, train_y_zero])

    indeces = np.arange(len(y_train))
    np.random.shuffle(indeces)
    X_train = X_train[indeces]
    y_train = y_train[indeces]


    indeces = np.arange(len(y_test))
    np.random.shuffle(indeces)
    X_test = X_test[indeces]
    y_test = y_test[indeces]

    return X_train, X_test, y_train, y_test

# %%
x_train, x_test, y_train, y_test = stratified_train_test_split(x, y, 0.3, 10)

# %% [markdown]
# # Checking if the ratio is Preserved

# %%
print("Inter-class ratio in original set:", len(np.argwhere(x == 1))/len(np.argwhere(x == 0)))
print("Inter-class ratio in train set:", len(np.argwhere(y_train == 1))/len(np.argwhere(y_train == 0)))
print("Inter-class ratio in test set:", len(np.argwhere(y_test == 1))/len(np.argwhere(y_test == 0)))
print('\n')
# Out:
# Inter-class ratio in original set: 0.08292682926829269
# Inter-class ratio in train set: 1.380952380952381
# Inter-class ratio in test set: 1.3214285714285714

# %%
x_train = x_train.astype(int)
y_train = y_train.astype(int)
x_test = x_test.astype(int)
y_test = y_test.astype(int)

# %%
model = LogisticRegression(max_iter=5)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=5, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
probabilities = model.predict_proba(x_test)

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# # Computing The Confusion Matrix

# %%
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'], margins=True)
confusion_matrix
# Out:
# Predicted   0   1  All
# Actual
# 0          19   9   28
# 1          19  18   37
# All        38  27   65

# %%
class_name = data.drop(['YEAR', 'PRIORITY', 'DAY', 'HOUR', 'HUNDRED_BLOCK', 'Latitude', 'Longitude', 'MINUTE'], axis=1)
class_name = class_name.columns

# %%
def plot_confusion_matrix(confusion_matrix, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.matshow(confusion_matrix, cmap=cmap) 
    plt.colorbar()
    tick_marks = np.arange(len(confusion_matrix.columns))
    plt.xticks(tick_marks, confusion_matrix.columns, rotation=45)
    plt.yticks(tick_marks, confusion_matrix.index)
    plt.ylabel(confusion_matrix.index.name)
    plt.xlabel(confusion_matrix.columns.name)

plot_confusion_matrix(confusion_matrix)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (0, 0)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-143-888630cdae6a> in <module>()
#      19
#      20 plt.figure()
# ...

# %%
confusion_matrix = abs(np.ravel(confusion_matrix))

# %%
TN = confusion_matrix[0]
FN = confusion_matrix[3]
FP = confusion_matrix[1]
TP = confusion_matrix[4]

# %% [markdown]
# # Computing Metrics from Confusion Matrix

# %%
def cal_accuracy(TP, TN, FP, FN):
    Accuracy = (TP + TN) / float(TP + TN + FP + FN)
    print ("Classification Accuracy : ", Accuracy * 100,"%")
    
    print ("Classification Error : ",
        (FP + FN) / float(TP + TN + FP + FN)*100,"%")
    
    print ("True Positive Rate or Sensitivity : ",
           (TP / float(FN + TP))*100,"%")
    
    Precision = TP / float(TP + FP)
    print ("Precision : ", Precision * 100,"%")
           
    print ("True Negative Rate or Specificity : ",
           TN / float(TN + FP)*100,"%")
    
    Recall = TP / float(TP + FN)
    print ("Recall : ",Recall * 100,"%")
    
    FPR = FP / float(TN + FP)
    print ("False Positive Rate : ",FPR * 100,"%")
    
    F1_score = (2 * Precision * Recall) / float(Precision + Recall)
    print ("F1 Score : ",F1_score * 100,"%")

# %%
cal_accuracy(TP, TN, FP, FN)
# Out:
# Classification Accuracy :  56.9230769231 %
# Classification Error :  43.0769230769 %
# True Positive Rate or Sensitivity :  48.6486486486 %
# Precision :  66.6666666667 %
# True Negative Rate or Specificity :  67.8571428571 %
# Recall :  48.6486486486 %
# False Positive Rate :  32.1428571429 %
# F1 Score :  56.25 %

# %%
class ROC:
    """
    ROC curve builder class.
    Classes are assumed to be binary

    """
    # results is an numpy array formed by stacking together fpr, tpr and corresponding thresholds.
    # use results for analysis
    results = None

    def __init__(self, proba, true_labels, pos_label_value, pos_label=1):
        """
        Use these values in calc_tpr_fpr() method

        :param proba: numpy array of class probabilities
        :param true_labels: numpy array of true labels
        :param pos_label_value: The value of the positive label (usually 1)
        :param pos_label: The relative order of positive label in proba
        """
        self.proba = proba
        self.true_labels = true_labels
        self.pos_label_value = pos_label_value
        self.pos_label = pos_label

    def plot(self):
        """
        Plots an ROC curve using True Positive Rate and False Positive rate lists calculated from __calc_tpr_fpr
        Calculates and outputs AUC score on the same graph
        """
        tpr, fpr, thresholds = self.__calc_tpr_fpr()
        self.results = np.column_stack((tpr, fpr, thresholds))

        fig = plt.figure()
        plt.plot(fpr, tpr, label='ROC Plot')
        fig.suptitle('ROC Plot')
        plt.xlabel('True Negative Rate')
        plt.ylabel('True Positive Rate')
        plt.legend()

    def __calc_tpr_fpr(self):
        """
        Calculates True Positive Rate, False Positive Rate and thresholds lists

        First, sorts probabilities of positive label in decreasing order
        Next, moving towards the least probability locates a threshold between instances with opposite classes
        (keeping instances with the same confidence value on the same side of threshold),
        computes TPR, FPR for instances above threshold and puts them in the lists

        :return:
        tpr: list
        fpr: list
        thresholds: list
        """

        tpr = [0]
        fpr = [0]
        thresholds = [1]

        TP = 0
        FN = (self.true_labels == 1).sum()
        TN = (self.true_labels == 0).sum()
        FP = 0

        prob_of_positive = self.proba[:, self.pos_label]
        index_sorted = np.argsort(-prob_of_positive)

        sorted_prob = prob_of_positive[index_sorted]
        sorted_labels = self.true_labels[index_sorted]

        for i in range(0, len(sorted_labels) - 1):
            if sorted_labels[i] == 1:
                FN -= 1
                TP += 1
            if sorted_labels[i] == 0:
                TN -= 1
                FP += 1

            if sorted_labels[i] != sorted_labels[i+1]:
                tpr.append(TP/(TP + FN))
                fpr.append((FP/(TN + FP)))
                thresholds.append(sorted_prob[i])

        thresholds.append(0)
        tpr.append(1)
        fpr.append(1)

#         print("FPR = ", fpr)
#         print("TPR = ", tpr)

        fig = plt.figure()
        plt.plot(fpr, label='FPR')
        plt.plot(tpr, label='TPR')
        plt.plot(thresholds, label='Thresholds')
        fig.suptitle('FPR, TPR and Thresholds Plot')
        plt.xlabel('True Negative Rate')
        plt.ylabel('True Positive Rate')
        plt.legend()
        plt.show()

        return tpr, fpr, thresholds

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=5, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# # Building an ROC curve

# %%
roc = ROC(probabilities, y_test, 1)

# %%
roc.plot()
plt.show()
